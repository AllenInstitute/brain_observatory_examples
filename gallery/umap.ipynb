# %%
from allensdk.core.brain_observatory_cache import BrainObservatoryCache

# %%
boc = BrainObservatoryCache(manifest_file='/local1/data/boc/manifest.json',)

# %%
oeid = 541206592

# Initializations:
nwb_dataset = boc.get_ophys_experiment_data(oeid)

# %%
time, traces = nwb_dataset.get_dff_traces()

# %%
traces = traces.T

# %%
from umap import UMAP

# %%
reducer = UMAP()

# %%
reduced = reducer.fit_transform(traces)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.jointplot(reduced[:,0],reduced[:,1],kind='hex')
# Out:
# /home/justink/anaconda3/envs/umap/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/justink/anaconda3/envs/umap/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
traces.shape
# Out:
# (114118, 154)
